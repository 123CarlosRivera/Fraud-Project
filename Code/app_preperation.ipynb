# %% [markdown]
# ## ```Imports```
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, plot_confusion_matrix

import pickle

# %%
fraud_df = pd.read_csv('/Users/crivera/Desktop/capstone-dsir82/capstone_data/final_model.csv')
fraud_df = fraud_df[fraud_df['state']=='NY']

# %%
fraud = fraud_df.copy()
fraud = pd.get_dummies(data=fraud, columns=['gender','city','category','merchant'])
fraud.drop(columns=['trans_date_trans_time','lat','long','job','merch_lat','merch_long','dob','is_fraud','state'], inplace=True)
fraud.shape
# Out:
# (83501, 781)

# %%
with open('app_model/dt_ny.pkl', 'rb') as pickle_in:
        dt = pickle.load(pickle_in)

# %%
dt.n_features_
# Out:
# 781

# %% [markdown]
# ## ```App Preperations```
# ---
# 1. Prepare tuples for streamlit selectbox
# 2. Prepare merchant dict

# %%
sorted(tuple([city for city in fraud_df['city'].unique()]))
# Out:
# ['Albany',
#  'Allentown',
#  'Altona',
#  'Armonk',
#  'Barneveld',
#  'Beacon',
#  'Belfast',
#  'Bellmore',
#  'Big Indian',
#  'Breesport',
#  'Bronx',
#  'Brooklyn',
#  'Brownville',
#  'Camden',
#  'Chatham',
#  'Cottekill',
#  'Cowlesville',
#  'De Lancey',
#  'Downsville',
#  'East Rochester',
#  'Falconer',
#  'Farmington',
#  'Garrattsville',
#  'Greenport',
#  'Hannawa Falls',
#  'Howes Cave',
#  'Hudson',
#  'Irvington',
#  'Jefferson',
#  'Jordanville',
#  'Knowlesville',
#  'Lowville',
#  'Margaretville',
#  'Medford',
#  'Melville',
#  'Montrose',
#  'Moriches',
#  'Mount Morris',
#  'Mount Vernon',
#  'Nanuet',
#  'New York City',
#  'Newark Valley',
#  'North Tonawanda',
#  'Northport',
#  'Oak Hill',
#  'Oakdale',
#  'Orangeburg',
#  'Orient',
#  'Oriskany Falls',
#  'Palmyra',
#  'Phelps',
#  'Pomona',
#  'Port Ewen',
#  'Port Gibson',
#  'Rock Tavern',
#  'Saint Bonaventure',
#  'Shelter Island',
#  'South Richmond Hill',
#  'Springfield Gardens',
#  'Stittville',
#  'Tupper Lake',
#  'West Chazy',
#  'West Eaton',
#  'West Harrison',
#  'West Henrietta',
#  'West Sayville',
#  'Westhampton Beach']

# %%
sorted(tuple([category for category in fraud['category'].unique()]))
# Out:
# ['entertainment',
#  'food_dining',
#  'gas_transport',
#  'grocery_net',
#  'grocery_pos',
#  'health_fitness',
#  'home',
#  'kids_pets',
#  'misc_net',
#  'misc_pos',
#  'personal_care',
#  'shopping_net',
#  'shopping_pos',
#  'travel']

# %%
len(sorted(tuple([merch for merch in fraud['merchant'].unique()])))
# Out:
# 693

# %%
cities = [col for col in X_train.columns if col.startswith('city')]
idx = list(range(0,67))
city_idx_dict = dict(zip(cities,idx))
city_idx_dict
# Out:
# {'city_pop': 0,
#  'city_Albany': 1,
#  'city_Allentown': 2,
#  'city_Altona': 3,
#  'city_Armonk': 4,
#  'city_Barneveld': 5,
#  'city_Beacon': 6,
#  'city_Belfast': 7,
#  'city_Bellmore': 8,
#  'city_Big Indian': 9,
#  'city_Breesport': 10,
#  'city_Bronx': 11,
#  'city_Brooklyn': 12,
#  'city_Brownville': 13,
#  'city_Camden': 14,
#  'city_Chatham': 15,
#  'city_Cottekill': 16,
#  'city_Cowlesville': 17,
#  'city_De Lancey': 18,
#  'city_Downsville': 19,
#  'city_East Rochester': 20,
#  'city_Falconer': 21,
#  'city_Farmington': 22,
#  'city_Garrattsville': 23,
#  'city_Greenport': 24,
#  'city_Hannawa Falls': 25,
#  'city_Howes Cave': 26,
#  'city_Hudson': 27,
#  'city_Irvington': 28,
#  'city_Jefferson': 29,
#  'city_Jordanville': 30,
#  'city_Knowlesville': 31,
#  'city_Lowville': 32,
#  'city_Margaretville': 33,
#  'city_Medford': 34,
#  'city_Melville': 35,
#  'city_Montrose': 36,
#  'city_Moriches': 37,
#  'city_Mount Morris': 38,
#  'city_Mount Vernon': 39,
#  'city_Nanuet': 40,
#  'city_New York City': 41,
#  'city_Newark Valley': 42,
#  'city_North Tonawanda': 43,
#  'city_Northport': 44,
#  'city_Oak Hill': 45,
#  'city_Oakdale': 46,
#  'city_Orangeburg': 47,
#  'city_Orient': 48,
#  'city_Oriskany Falls': 49,
#  'city_Palmyra': 50,
#  'city_Phelps': 51,
#  'city_Pomona': 52,
#  'city_Port Ewen': 53,
#  'city_Port Gibson': 54,
#  'city_Rock Tavern': 55,
#  'city_Saint Bonaventure': 56,
#  'city_Shelter Island': 57,
#  'city_South Richmond Hill': 58,
#  'city_Springfield Gardens': 59,
#  'city_Stittville': 60,
#  'city_Tupper Lake': 61,
#  'city_West Chazy': 62,
#  'city_West Eaton': 63,
#  'city_West Harrison': 64,
#  'city_West Henrietta': 65,
#  'city_West Sayville': 66}

# %%
print(len(fraud['category'].unique()))
print(X_train.shape)
X_train.columns[782-14:782]
# Out:
# 14
# (116124, 782)
# Index(['merchant_fraud_Wuckert, Wintheiser and Friesen',
#        'merchant_fraud_Wuckert-Goldner', 'merchant_fraud_Wuckert-Walter',
#        'merchant_fraud_Yost, Block and Koepp',
#        'merchant_fraud_Yost, Schamberger and Windler',
#        'merchant_fraud_Yost-Rogahn', 'merchant_fraud_Zboncak LLC',
#        'merchant_fraud_Zboncak Ltd',
#        'merchant_fraud_Zboncak, Rowe and Murazik',
#        'merchant_fraud_Zemlak Group',
#        'merchant_fraud_Zemlak, Tillman and Cremin',
#        'merchant_fraud_Ziemann-Waters',
#        'merchant_fraud_Zieme, Bode and Dooley', 'merchant_fraud_Zulauf LLC'],
#       dtype='object')

# %%
merchant = [col for col in X_train.columns if col.startswith('merchant')]
idx = list(range(0,693))
merchant_idx_dict = dict(zip(merchant,idx))
merchant_idx_dict
# Out:
# {'merchant_fraud_Abbott-Rogahn': 0,
#  'merchant_fraud_Abbott-Steuber': 1,
#  'merchant_fraud_Abernathy and Sons': 2,
#  'merchant_fraud_Abshire PLC': 3,
#  'merchant_fraud_Adams, Kovacek and Kuhlman': 4,
#  'merchant_fraud_Adams-Barrows': 5,
#  'merchant_fraud_Altenwerth, Cartwright and Koss': 6,
#  'merchant_fraud_Altenwerth-Kilback': 7,
#  'merchant_fraud_Ankunding LLC': 8,
#  'merchant_fraud_Ankunding-Carroll': 9,
#  'merchant_fraud_Armstrong, Walter and Gottlieb': 10,
#  'merchant_fraud_Auer LLC': 11,
#  'merchant_fraud_Auer-Mosciski': 12,
#  'merchant_fraud_Auer-West': 13,
#  'merchant_fraud_Bahringer Group': 14,
#  'merchant_fraud_Bahringer, Bergnaum and Quitzon': 15,
#  'merchant_fraud_Bahringer, Osinski and Block': 16,
#  'merchant_fraud_Bahringer, Schoen and Corkery': 17,
#  'merchant_fraud_Bahringer-Larson': 18,
#  'merchant_fraud_Bahringer-Streich': 19,
#  'merchant_fraud_Bailey-Morar': 20,
#  'merchant_fraud_Balistreri-Nader': 21,
#  'merchant_fraud_Barrows PLC': 22,
#  'merchant_fraud_Bartoletti and Sons': 23,
#  'merchant_fraud_Bartoletti-Wunsch': 24,
#  'merchant_fraud_Barton Inc': 25,
#  'merchant_fraud_Barton LLC': 26,
#  'merchant_fraud_Bashirian Group': 27,
#  'merchant_fraud_Bauch-Blanda': 28,
#  'merchant_fraud_Bauch-Raynor': 29,
#  'merchant_fraud_Baumbach Ltd': 30,
#  'merchant_fraud_Baumbach, Feeney and Morar': 31,
#  'merchant_fraud_Baumbach, Hodkiewicz and Walsh': 32,
#  'merchant_fraud_Baumbach, Strosin and Nicolas': 33,
#  'merchant_fraud_Bechtelar-Rippin': 34,
#  'merchant_fraud_Becker, Harris and Harvey': 35,
#  'merchant_fraud_Bednar Group': 36,
#  'merchant_fraud_Bednar Inc': 37,
#  'merchant_fraud_Bednar PLC': 38,
#  'merchant_fraud_Beer-Jast': 39,
#  'merchant_fraud_Beier LLC': 40,
#  'merchant_fraud_Beier and Sons': 41,
#  'merchant_fraud_Beier-Hyatt': 42,
#  'merchant_fraud_Berge LLC': 43,
#  'merchant_fraud_Berge, Kautzer and Harris': 44,
#  'merchant_fraud_Berge-Hills': 45,
#  'merchant_fraud_Berge-Ullrich': 46,
#  'merchant_fraud_Bernhard Inc': 47,
#  'merchant_fraud_Bernhard, Grant and Langworth': 48,
#  'merchant_fraud_Bernhard-Lesch': 49,
#  'merchant_fraud_Bernier and Sons': 50,
#  'merchant_fraud_Bernier, Streich and Jewess': 51,
#  'merchant_fraud_Bernier, Volkman and Hoeger': 52,
#  'merchant_fraud_Bins, Balistreri and Beatty': 53,
#  'merchant_fraud_Bins-Howell': 54,
#  'merchant_fraud_Bins-Rice': 55,
#  'merchant_fraud_Bins-Tillman': 56,
#  'merchant_fraud_Block Group': 57,
#  'merchant_fraud_Block-Hauck': 58,
#  'merchant_fraud_Block-Parisian': 59,
#  'merchant_fraud_Bode-Rempel': 60,
#  'merchant_fraud_Bode-Schuster': 61,
#  'merchant_fraud_Boehm, Block and Jakubowski': 62,
#  'merchant_fraud_Boehm, Predovic and Reinger': 63,
#  'merchant_fraud_Bogisich Inc': 64,
#  'merchant_fraud_Bogisich-Homenick': 65,
#  'merchant_fraud_Bogisich-Weimann': 66,
#  'merchant_fraud_Botsford Ltd': 67,
#  'merchant_fraud_Botsford PLC': 68,
#  'merchant_fraud_Botsford and Sons': 69,
#  'merchant_fraud_Boyer PLC': 70,
#  'merchant_fraud_Boyer-Haley': 71,
#  'merchant_fraud_Boyer-Reichert': 72,
#  'merchant_fraud_Bradtke PLC': 73,
#  'merchant_fraud_Bradtke, Torp and Bahringer': 74,
#  'merchant_fraud_Breitenberg LLC': 75,
#  'merchant_fraud_Breitenberg-Hermiston': 76,
#  'merchant_fraud_Brekke and Sons': 77,
#  'merchant_fraud_Brown Inc': 78,
#  'merchant_fraud_Brown PLC': 79,
#  'merchant_fraud_Brown, Homenick and Lesch': 80,
#  'merchant_fraud_Brown-Greenholt': 81,
#  'merchant_fraud_Bruen-Yost': 82,
#  'merchant_fraud_Buckridge PLC': 83,
#  'merchant_fraud_Carroll PLC': 84,
#  'merchant_fraud_Cartwright PLC': 85,
#  'merchant_fraud_Cartwright-Harris': 86,
#  'merchant_fraud_Casper, Hand and Zulauf': 87,
#  'merchant_fraud_Cassin-Harvey': 88,
#  'merchant_fraud_Champlin and Sons': 89,
#  'merchant_fraud_Champlin, Rolfson and Connelly': 90,
#  'merchant_fraud_Champlin-Casper': 91,
#  'merchant_fraud_Christiansen, Goyette and Schamberger': 92,
#  'merchant_fraud_Christiansen-Gusikowski': 93,
#  'merchant_fraud_Cole PLC': 94,
#  'merchant_fraud_Cole, Hills and Jewess': 95,
#  'merchant_fraud_Collier Inc': 96,
#  'merchant_fraud_Collier LLC': 97,
#  'merchant_fraud_Connelly PLC': 98,
#  'merchant_fraud_Connelly, Reichert and Fritsch': 99,
#  'merchant_fraud_Connelly-Carter': 100,
#  'merchant_fraud_Conroy Ltd': 101,
#  'merchant_fraud_Conroy, Balistreri and Gorczany': 102,
#  'merchant_fraud_Conroy-Cruickshank': 103,
#  'merchant_fraud_Conroy-Emard': 104,
#  'merchant_fraud_Cormier LLC': 105,
#  'merchant_fraud_Cormier, Stracke and Thiel': 106,
#  'merchant_fraud_Corwin-Collins': 107,
#  'merchant_fraud_Corwin-Gorczany': 108,
#  'merchant_fraud_Corwin-Romaguera': 109,
#  'merchant_fraud_Cremin, Hamill and Reichel': 110,
#  'merchant_fraud_Crist, Jakubowski and Littel': 111,
#  'merchant_fraud_Crona and Sons': 112,
#  'merchant_fraud_Cronin, Kshlerin and Weber': 113,
#  'merchant_fraud_Crooks and Sons': 114,
#  'merchant_fraud_Cruickshank-Mills': 115,
#  'merchant_fraud_Cummerata-Hilpert': 116,
#  'merchant_fraud_Cummerata-Jones': 117,
#  'merchant_fraud_Cummings Group': 118,
#  'merchant_fraud_Cummings LLC': 119,
#  'merchant_fraud_Dach-Borer': 120,
#  'merchant_fraud_Dach-Nader': 121,
#  'merchant_fraud_Dare, Casper and Bartoletti': 122,
#  'merchant_fraud_Dare, Fritsch and Zboncak': 123,
#  'merchant_fraud_Dare-Gibson': 124,
#  'merchant_fraud_Dare-Marvin': 125,
#  'merchant_fraud_Daugherty LLC': 126,
#  'merchant_fraud_Daugherty, Pouros and Beahan': 127,
#  'merchant_fraud_Daugherty-Thompson': 128,
#  'merchant_fraud_Deckow-Dare': 129,
#  "merchant_fraud_Deckow-O'Conner": 130,
#  'merchant_fraud_Denesik and Sons': 131,
#  'merchant_fraud_Denesik, Powlowski and Pouros': 132,
#  'merchant_fraud_Dibbert and Sons': 133,
#  'merchant_fraud_Dibbert-Green': 134,
#  'merchant_fraud_Dicki Ltd': 135,
#  'merchant_fraud_Dickinson Ltd': 136,
#  'merchant_fraud_Dickinson-Rempel': 137,
#  'merchant_fraud_Dietrich-Fadel': 138,
#  'merchant_fraud_Donnelly LLC': 139,
#  'merchant_fraud_Donnelly PLC': 140,
#  'merchant_fraud_Dooley Inc': 141,
#  'merchant_fraud_Dooley-Thompson': 142,
#  'merchant_fraud_Douglas, DuBuque and McKenzie': 143,
#  'merchant_fraud_Douglas, Schneider and Turner': 144,
#  'merchant_fraud_Douglas-White': 145,
#  'merchant_fraud_Doyle Ltd': 146,
#  'merchant_fraud_DuBuque LLC': 147,
#  'merchant_fraud_Durgan, Gislason and Spencer': 148,
#  'merchant_fraud_Durgan-Auer': 149,
#  'merchant_fraud_Ebert-Daugherty': 150,
#  'merchant_fraud_Effertz LLC': 151,
#  'merchant_fraud_Effertz, Welch and Schowalter': 152,
#  'merchant_fraud_Eichmann, Bogan and Rodriguez': 153,
#  'merchant_fraud_Eichmann, Hayes and Treutel': 154,
#  'merchant_fraud_Eichmann-Kilback': 155,
#  'merchant_fraud_Eichmann-Russel': 156,
#  'merchant_fraud_Emard Inc': 157,
#  'merchant_fraud_Emmerich-Luettgen': 158,
#  'merchant_fraud_Emmerich-Rau': 159,
#  'merchant_fraud_Erdman-Durgan': 160,
#  'merchant_fraud_Erdman-Ebert': 161,
#  'merchant_fraud_Erdman-Kertzmann': 162,
#  'merchant_fraud_Erdman-Schaden': 163,
#  'merchant_fraud_Ernser-Feest': 164,
#  'merchant_fraud_Ernser-Lynch': 165,
#  'merchant_fraud_Fadel Inc': 166,
#  'merchant_fraud_Fadel, Mertz and Rippin': 167,
#  'merchant_fraud_Fadel-Hilpert': 168,
#  'merchant_fraud_Fahey Inc': 169,
#  'merchant_fraud_Feil, Hilpert and Koss': 170,
#  'merchant_fraud_Feil-Morar': 171,
#  'merchant_fraud_Ferry, Lynch and Kautzer': 172,
#  'merchant_fraud_Ferry, Reichel and DuBuque': 173,
#  'merchant_fraud_Fisher Inc': 174,
#  'merchant_fraud_Fisher-Schowalter': 175,
#  'merchant_fraud_Flatley Group': 176,
#  'merchant_fraud_Flatley-Durgan': 177,
#  'merchant_fraud_Frami Group': 178,
#  'merchant_fraud_Friesen Inc': 179,
#  'merchant_fraud_Friesen Ltd': 180,
#  "merchant_fraud_Friesen-D'Amore": 181,
#  'merchant_fraud_Friesen-Ortiz': 182,
#  'merchant_fraud_Friesen-Stamm': 183,
#  'merchant_fraud_Fritsch LLC': 184,
#  'merchant_fraud_Fritsch and Sons': 185,
#  'merchant_fraud_Funk Group': 186,
#  'merchant_fraud_Gaylord-Powlowski': 187,
#  'merchant_fraud_Gerhold LLC': 188,
#  'merchant_fraud_Gerlach Inc': 189,
#  'merchant_fraud_Gibson-Deckow': 190,
#  'merchant_fraud_Gislason Group': 191,
#  'merchant_fraud_Gleason and Sons': 192,
#  'merchant_fraud_Gleason-Macejkovic': 193,
#  'merchant_fraud_Goldner, Kovacek and Abbott': 194,
#  'merchant_fraud_Goldner-Lemke': 195,
#  'merchant_fraud_Goodwin-Nitzsche': 196,
#  'merchant_fraud_Gottlieb Group': 197,
#  'merchant_fraud_Gottlieb, Considine and Schultz': 198,
#  'merchant_fraud_Gottlieb-Hansen': 199,
#  'merchant_fraud_Goyette Inc': 200,
#  'merchant_fraud_Goyette, Howell and Collier': 201,
#  'merchant_fraud_Goyette-Gerhold': 202,
#  'merchant_fraud_Goyette-Herzog': 203,
#  'merchant_fraud_Graham and Sons': 204,
#  'merchant_fraud_Graham, Hegmann and Hammes': 205,
#  'merchant_fraud_Greenfelder, Bartoletti and Davis': 206,
#  'merchant_fraud_Greenholt Ltd': 207,
#  'merchant_fraud_Greenholt, Jacobi and Gleason': 208,
#  "merchant_fraud_Greenholt, O'Hara and Balistreri": 209,
#  'merchant_fraud_Grimes LLC': 210,
#  'merchant_fraud_Gulgowski LLC': 211,
#  'merchant_fraud_Gutmann Ltd': 212,
#  'merchant_fraud_Gutmann, McLaughlin and Wiza': 213,
#  'merchant_fraud_Gutmann-Upton': 214,
#  'merchant_fraud_Haag-Blanda': 215,
#  'merchant_fraud_Hackett Group': 216,
#  'merchant_fraud_Hackett-Lueilwitz': 217,
#  'merchant_fraud_Hagenes, Hermann and Stroman': 218,
#  'merchant_fraud_Hagenes, Kohler and Hoppe': 219,
#  'merchant_fraud_Hahn, Bahringer and McLaughlin': 220,
#  'merchant_fraud_Hahn, Douglas and Schowalter': 221,
#  'merchant_fraud_Haley Group': 222,
#  'merchant_fraud_Haley, Batz and Auer': 223,
#  'merchant_fraud_Haley, Jewess and Bechtelar': 224,
#  'merchant_fraud_Halvorson Group': 225,
#  "merchant_fraud_Hamill-D'Amore": 226,
#  'merchant_fraud_Hamill-Daugherty': 227,
#  'merchant_fraud_Hammes-Beatty': 228,
#  'merchant_fraud_Harber Inc': 229,
#  'merchant_fraud_Harris Group': 230,
#  'merchant_fraud_Harris Inc': 231,
#  'merchant_fraud_Harris, Gusikowski and Heaney': 232,
#  'merchant_fraud_Hartmann, Rowe and Hermann': 233,
#  'merchant_fraud_Hauck, Dietrich and Funk': 234,
#  'merchant_fraud_Hayes, Marquardt and Dibbert': 235,
#  'merchant_fraud_Heaney-Marquardt': 236,
#  'merchant_fraud_Heathcote LLC': 237,
#  'merchant_fraud_Heathcote, Yost and Kertzmann': 238,
#  'merchant_fraud_Heidenreich PLC': 239,
#  'merchant_fraud_Heller PLC': 240,
#  'merchant_fraud_Heller, Gutmann and Zieme': 241,
#  'merchant_fraud_Heller-Abshire': 242,
#  'merchant_fraud_Heller-Langosh': 243,
#  'merchant_fraud_Herman Inc': 244,
#  'merchant_fraud_Herman, Treutel and Dickens': 245,
#  'merchant_fraud_Hermann and Sons': 246,
#  'merchant_fraud_Hermann-Gaylord': 247,
#  'merchant_fraud_Hermiston, Pacocha and Smith': 248,
#  'merchant_fraud_Hermiston, Russel and Price': 249,
#  'merchant_fraud_Herzog Ltd': 250,
#  'merchant_fraud_Hettinger, McCullough and Fay': 251,
#  'merchant_fraud_Hickle Group': 252,
#  'merchant_fraud_Hills, Hegmann and Schaefer': 253,
#  'merchant_fraud_Hills-Boyer': 254,
#  'merchant_fraud_Hills-Olson': 255,
#  'merchant_fraud_Hills-Witting': 256,
#  'merchant_fraud_Hilpert-Conroy': 257,
#  'merchant_fraud_Hintz, Bauch and Smith': 258,
#  'merchant_fraud_Hintz-Bruen': 259,
#  'merchant_fraud_Hirthe-Beier': 260,
#  'merchant_fraud_Hodkiewicz, Prohaska and Paucek': 261,
#  'merchant_fraud_Homenick LLC': 262,
#  'merchant_fraud_Hoppe, Harris and Bednar': 263,
#  'merchant_fraud_Hoppe-Parisian': 264,
#  'merchant_fraud_Howe Ltd': 265,
#  'merchant_fraud_Howe PLC': 266,
#  'merchant_fraud_Hudson-Grady': 267,
#  'merchant_fraud_Hudson-Ratke': 268,
#  'merchant_fraud_Huel Ltd': 269,
#  'merchant_fraud_Huel, Hammes and Witting': 270,
#  'merchant_fraud_Huel-Langworth': 271,
#  'merchant_fraud_Huels-Hahn': 272,
#  'merchant_fraud_Huels-Nolan': 273,
#  'merchant_fraud_Hyatt, Russel and Gleichner': 274,
#  'merchant_fraud_Hyatt-Blick': 275,
#  'merchant_fraud_Jacobi Inc': 276,
#  'merchant_fraud_Jacobi and Sons': 277,
#  'merchant_fraud_Jakubowski Group': 278,
#  'merchant_fraud_Jakubowski Inc': 279,
#  'merchant_fraud_Jaskolski-Dibbert': 280,
#  'merchant_fraud_Jaskolski-Vandervort': 281,
#  'merchant_fraud_Jast Ltd': 282,
#  'merchant_fraud_Jast and Sons': 283,
#  'merchant_fraud_Jast-McDermott': 284,
#  'merchant_fraud_Jenkins, Hauck and Friesen': 285,
#  'merchant_fraud_Jerde-Hermann': 286,
#  'merchant_fraud_Jewess LLC': 287,
#  'merchant_fraud_Johns Inc': 288,
#  'merchant_fraud_Johns-Hoeger': 289,
#  'merchant_fraud_Johnson, Runolfsdottir and Mayer': 290,
#  'merchant_fraud_Johnston, Nikolaus and Maggio': 291,
#  'merchant_fraud_Johnston-Casper': 292,
#  'merchant_fraud_Jones, Sawayn and Romaguera': 293,
#  'merchant_fraud_Kassulke Inc': 294,
#  'merchant_fraud_Kassulke PLC': 295,
#  'merchant_fraud_Kautzer and Sons': 296,
#  'merchant_fraud_Keeling-Crist': 297,
#  'merchant_fraud_Kemmer-Buckridge': 298,
#  'merchant_fraud_Kemmer-Reinger': 299,
#  'merchant_fraud_Kerluke Inc': 300,
#  'merchant_fraud_Kerluke PLC': 301,
#  'merchant_fraud_Kerluke, Considine and Macejkovic': 302,
#  'merchant_fraud_Kerluke, Kertzmann and Wiza': 303,
#  'merchant_fraud_Kerluke-Abshire': 304,
#  'merchant_fraud_Kertzmann LLC': 305,
#  'merchant_fraud_Kessler Group': 306,
#  'merchant_fraud_Kessler Inc': 307,
#  'merchant_fraud_Kiehn Inc': 308,
#  'merchant_fraud_Kiehn-Emmerich': 309,
#  'merchant_fraud_Kihn Inc': 310,
#  'merchant_fraud_Kihn, Abernathy and Douglas': 311,
#  'merchant_fraud_Kihn, Brakus and Goyette': 312,
#  'merchant_fraud_Kihn-Fritsch': 313,
#  'merchant_fraud_Kihn-Schuster': 314,
#  'merchant_fraud_Kilback Group': 315,
#  'merchant_fraud_Kilback LLC': 316,
#  'merchant_fraud_Kilback and Sons': 317,
#  'merchant_fraud_Kilback, Nitzsche and Leffler': 318,
#  'merchant_fraud_Kirlin and Sons': 319,
#  'merchant_fraud_Klein Group': 320,
#  'merchant_fraud_Kling Inc': 321,
#  'merchant_fraud_Kling, Howe and Schneider': 322,
#  'merchant_fraud_Kling-Ernser': 323,
#  'merchant_fraud_Kling-Grant': 324,
#  'merchant_fraud_Klocko LLC': 325,
#  'merchant_fraud_Klocko, Runolfsdottir and Breitenberg': 326,
#  'merchant_fraud_Koelpin and Sons': 327,
#  'merchant_fraud_Koepp-Parker': 328,
#  'merchant_fraud_Koepp-Witting': 329,
#  'merchant_fraud_Kohler, Lindgren and Koelpin': 330,
#  'merchant_fraud_Konopelski, Schneider and Hartmann': 331,
#  'merchant_fraud_Koss and Sons': 332,
#  'merchant_fraud_Koss, Hansen and Lueilwitz': 333,
#  'merchant_fraud_Koss, McLaughlin and Mayer': 334,
#  'merchant_fraud_Kovacek Ltd': 335,
#  'merchant_fraud_Kovacek, Dibbert and Ondricka': 336,
#  'merchant_fraud_Kozey-Boehm': 337,
#  'merchant_fraud_Kozey-Kuhlman': 338,
#  'merchant_fraud_Kozey-McDermott': 339,
#  'merchant_fraud_Kris-Kertzmann': 340,
#  'merchant_fraud_Kris-Padberg': 341,
#  'merchant_fraud_Kris-Weimann': 342,
#  'merchant_fraud_Kub PLC': 343,
#  'merchant_fraud_Kub-Heaney': 344,
#  'merchant_fraud_Kuhic Inc': 345,
#  'merchant_fraud_Kuhic LLC': 346,
#  'merchant_fraud_Kuhic, Bins and Pfeffer': 347,
#  'merchant_fraud_Kuhn Group': 348,
#  'merchant_fraud_Kuhn LLC': 349,
#  'merchant_fraud_Kulas Group': 350,
#  'merchant_fraud_Kunde-Sanford': 351,
#  'merchant_fraud_Kunze Inc': 352,
#  'merchant_fraud_Kunze, Larkin and Mayert': 353,
#  'merchant_fraud_Kuphal-Bartoletti': 354,
#  'merchant_fraud_Kuphal-Predovic': 355,
#  'merchant_fraud_Kuphal-Toy': 356,
#  'merchant_fraud_Kutch Group': 357,
#  'merchant_fraud_Kutch LLC': 358,
#  'merchant_fraud_Kutch and Sons': 359,
#  'merchant_fraud_Kutch, Hermiston and Farrell': 360,
#  'merchant_fraud_Kutch, Steuber and Gerhold': 361,
#  'merchant_fraud_Kutch-Ferry': 362,
#  'merchant_fraud_Kutch-Hegmann': 363,
#  'merchant_fraud_Kutch-Wilderman': 364,
#  'merchant_fraud_Kuvalis Ltd': 365,
#  'merchant_fraud_Labadie LLC': 366,
#  'merchant_fraud_Labadie, Treutel and Bode': 367,
#  'merchant_fraud_Lakin, Ferry and Beatty': 368,
#  'merchant_fraud_Lang, Towne and Schuppe': 369,
#  'merchant_fraud_Langosh, Wintheiser and Hyatt': 370,
#  'merchant_fraud_Langworth LLC': 371,
#  'merchant_fraud_Langworth, Boehm and Gulgowski': 372,
#  'merchant_fraud_Larkin Ltd': 373,
#  'merchant_fraud_Larkin, Stracke and Greenfelder': 374,
#  'merchant_fraud_Larson, Quitzon and Spencer': 375,
#  'merchant_fraud_Larson-Moen': 376,
#  'merchant_fraud_Leannon-Nikolaus': 377,
#  'merchant_fraud_Leannon-Ward': 378,
#  'merchant_fraud_Lebsack and Sons': 379,
#  'merchant_fraud_Ledner, Hartmann and Feest': 380,
#  'merchant_fraud_Ledner-Pfannerstill': 381,
#  'merchant_fraud_Leffler-Goldner': 382,
#  'merchant_fraud_Lehner, Mosciski and King': 383,
#  'merchant_fraud_Lehner, Reichert and Mills': 384,
#  'merchant_fraud_Lemke and Sons': 385,
#  'merchant_fraud_Lemke-Gutmann': 386,
#  'merchant_fraud_Lesch Ltd': 387,
#  "merchant_fraud_Lesch, D'Amore and Brown": 388,
#  'merchant_fraud_Lind, Huel and McClure': 389,
#  'merchant_fraud_Lind-Buckridge': 390,
#  'merchant_fraud_Little Ltd': 391,
#  'merchant_fraud_Little, Gutmann and Lynch': 392,
#  'merchant_fraud_Little-Gleichner': 393,
#  'merchant_fraud_Lockman Ltd': 394,
#  'merchant_fraud_Lockman, West and Runte': 395,
#  'merchant_fraud_Lowe, Dietrich and Erdman': 396,
#  'merchant_fraud_Lubowitz, Terry and Stracke': 397,
#  'merchant_fraud_Lubowitz-Walter': 398,
#  'merchant_fraud_Luettgen PLC': 399,
#  'merchant_fraud_Lynch Ltd': 400,
#  'merchant_fraud_Lynch-Mohr': 401,
#  'merchant_fraud_Lynch-Wisozk': 402,
#  'merchant_fraud_Macejkovic-Lesch': 403,
#  'merchant_fraud_Maggio-Fahey': 404,
#  'merchant_fraud_Mante Group': 405,
#  'merchant_fraud_Mante, Luettgen and Hackett': 406,
#  'merchant_fraud_Marks Inc': 407,
#  'merchant_fraud_Marvin-Lind': 408,
#  'merchant_fraud_Mayert Group': 409,
#  'merchant_fraud_McCullough Group': 410,
#  'merchant_fraud_McCullough LLC': 411,
#  'merchant_fraud_McCullough, Hudson and Schuster': 412,
#  'merchant_fraud_McDermott, Osinski and Morar': 413,
#  'merchant_fraud_McDermott-Rice': 414,
#  'merchant_fraud_McDermott-Weimann': 415,
#  'merchant_fraud_McGlynn-Heathcote': 416,
#  'merchant_fraud_McGlynn-Jaskolski': 417,
#  'merchant_fraud_McKenzie-Huels': 418,
#  'merchant_fraud_McLaughlin, Armstrong and Koepp': 419,
#  'merchant_fraud_Medhurst Inc': 420,
#  'merchant_fraud_Medhurst PLC': 421,
#  'merchant_fraud_Medhurst, Cartwright and Ebert': 422,
#  'merchant_fraud_Medhurst, Labadie and Gottlieb': 423,
#  'merchant_fraud_Metz, Russel and Metz': 424,
#  'merchant_fraud_Metz-Boehm': 425,
#  'merchant_fraud_Miller-Harris': 426,
#  'merchant_fraud_Miller-Hauck': 427,
#  'merchant_fraud_Moen, Reinger and Murphy': 428,
#  'merchant_fraud_Mohr Inc': 429,
#  'merchant_fraud_Mohr-Bayer': 430,
#  'merchant_fraud_Monahan, Bogisich and Ledner': 431,
#  'merchant_fraud_Monahan, Hermann and Johns': 432,
#  'merchant_fraud_Monahan-Morar': 433,
#  'merchant_fraud_Moore, Dibbert and Koepp': 434,
#  'merchant_fraud_Moore, Williamson and Emmerich': 435,
#  'merchant_fraud_Morar Inc': 436,
#  'merchant_fraud_Morissette LLC': 437,
#  'merchant_fraud_Morissette PLC': 438,
#  'merchant_fraud_Morissette, Weber and Wiegand': 439,
#  'merchant_fraud_Morissette-Schaefer': 440,
#  'merchant_fraud_Mosciski Group': 441,
#  'merchant_fraud_Mosciski, Gislason and Mertz': 442,
#  'merchant_fraud_Mosciski, Ziemann and Farrell': 443,
#  'merchant_fraud_Mraz-Herzog': 444,
#  'merchant_fraud_Mueller, Gerhold and Mueller': 445,
#  'merchant_fraud_Murray Ltd': 446,
#  'merchant_fraud_Murray-Smitham': 447,
#  'merchant_fraud_Nader-Heller': 448,
#  'merchant_fraud_Nader-Maggio': 449,
#  'merchant_fraud_Nicolas, Hills and McGlynn': 450,
#  'merchant_fraud_Nienow PLC': 451,
#  'merchant_fraud_Nienow, Ankunding and Collier': 452,
#  'merchant_fraud_Nienow, Barrows and Romaguera': 453,
#  'merchant_fraud_Nitzsche, Kessler and Wolff': 454,
#  'merchant_fraud_Nolan-Williamson': 455,
#  "merchant_fraud_O'Connell, Botsford and Hand": 456,
#  "merchant_fraud_O'Connell-Ullrich": 457,
#  "merchant_fraud_O'Hara-Wilderman": 458,
#  "merchant_fraud_O'Keefe-Hudson": 459,
#  "merchant_fraud_O'Keefe-Wisoky": 460,
#  "merchant_fraud_O'Reilly, Mohr and Purdy": 461,
#  'merchant_fraud_Okuneva, Schneider and Rau': 462,
#  'merchant_fraud_Olson, Becker and Koch': 463,
#  'merchant_fraud_Ortiz Group': 464,
#  'merchant_fraud_Osinski Inc': 465,
#  'merchant_fraud_Osinski, Ledner and Leuschke': 466,
#  'merchant_fraud_Pacocha-Bauch': 467,
#  "merchant_fraud_Pacocha-O'Reilly": 468,
#  'merchant_fraud_Pacocha-Weissnat': 469,
#  'merchant_fraud_Padberg-Rogahn': 470,
#  'merchant_fraud_Padberg-Sauer': 471,
#  'merchant_fraud_Padberg-Welch': 472,
#  'merchant_fraud_Pagac LLC': 473,
#  'merchant_fraud_Parisian and Sons': 474,
#  'merchant_fraud_Parisian, Schiller and Altenwerth': 475,
#  'merchant_fraud_Parker, Nolan and Trantow': 476,
#  'merchant_fraud_Parker-Kunde': 477,
#  'merchant_fraud_Paucek-Wiza': 478,
#  'merchant_fraud_Pfeffer LLC': 479,
#  'merchant_fraud_Pfeffer and Sons': 480,
#  'merchant_fraud_Pollich LLC': 481,
#  'merchant_fraud_Pouros, Walker and Spencer': 482,
#  'merchant_fraud_Pouros-Conroy': 483,
#  'merchant_fraud_Pouros-Haag': 484,
#  'merchant_fraud_Powlowski-Weimann': 485,
#  'merchant_fraud_Predovic Inc': 486,
#  'merchant_fraud_Price Inc': 487,
#  'merchant_fraud_Prohaska-Murray': 488,
#  'merchant_fraud_Prosacco LLC': 489,
#  'merchant_fraud_Prosacco, Kreiger and Kovacek': 490,
#  'merchant_fraud_Quitzon, Green and Bashirian': 491,
#  'merchant_fraud_Quitzon-Goyette': 492,
#  'merchant_fraud_Ratke and Sons': 493,
#  'merchant_fraud_Rau and Sons': 494,
#  'merchant_fraud_Rau-Grant': 495,
#  'merchant_fraud_Rau-Robel': 496,
#  'merchant_fraud_Raynor, Feest and Miller': 497,
#  'merchant_fraud_Raynor, Reinger and Hagenes': 498,
#  'merchant_fraud_Reichel Inc': 499,
#  'merchant_fraud_Reichel LLC': 500,
#  'merchant_fraud_Reichel, Bradtke and Blanda': 501,
#  'merchant_fraud_Reichert, Huels and Hoppe': 502,
#  'merchant_fraud_Reichert, Rowe and Mraz': 503,
#  'merchant_fraud_Reichert, Shanahan and Hayes': 504,
#  'merchant_fraud_Reichert-Weissnat': 505,
#  'merchant_fraud_Reilly LLC': 506,
#  'merchant_fraud_Reilly and Sons': 507,
#  'merchant_fraud_Reilly, Heaney and Cole': 508,
#  'merchant_fraud_Reinger, Weissnat and Strosin': 509,
#  'merchant_fraud_Rempel Inc': 510,
#  'merchant_fraud_Rempel PLC': 511,
#  'merchant_fraud_Renner Ltd': 512,
#  'merchant_fraud_Reynolds-Schinner': 513,
#  'merchant_fraud_Rippin, Kub and Mann': 514,
#  'merchant_fraud_Rippin-VonRueden': 515,
#  'merchant_fraud_Ritchie, Bradtke and Stiedemann': 516,
#  'merchant_fraud_Ritchie, Oberbrunner and Cremin': 517,
#  'merchant_fraud_Robel, Cummerata and Prosacco': 518,
#  'merchant_fraud_Roberts, Daniel and Macejkovic': 519,
#  'merchant_fraud_Roberts, Ryan and Smith': 520,
#  'merchant_fraud_Roberts-Beahan': 521,
#  'merchant_fraud_Rodriguez Group': 522,
#  'merchant_fraud_Rodriguez, Yost and Jenkins': 523,
#  'merchant_fraud_Rohan, White and Aufderhar': 524,
#  'merchant_fraud_Rolfson-Kunde': 525,
#  'merchant_fraud_Romaguera Ltd': 526,
#  'merchant_fraud_Romaguera and Sons': 527,
#  'merchant_fraud_Romaguera, Cruickshank and Greenholt': 528,
#  'merchant_fraud_Romaguera, Wehner and Tromp': 529,
#  'merchant_fraud_Roob LLC': 530,
#  'merchant_fraud_Roob, Conn and Tremblay': 531,
#  'merchant_fraud_Roob-Okuneva': 532,
#  'merchant_fraud_Rowe, Batz and Goodwin': 533,
#  'merchant_fraud_Rowe-Vandervort': 534,
#  'merchant_fraud_Ruecker Group': 535,
#  'merchant_fraud_Ruecker, Beer and Collier': 536,
#  'merchant_fraud_Ruecker-Mayert': 537,
#  'merchant_fraud_Runolfsdottir, Mueller and Hand': 538,
#  'merchant_fraud_Runolfsson and Sons': 539,
#  'merchant_fraud_Runte, Green and Emard': 540,
#  'merchant_fraud_Runte-Mohr': 541,
#  'merchant_fraud_Rutherford, Homenick and Bergstrom': 542,
#  'merchant_fraud_Rutherford-Mertz': 543,
#  'merchant_fraud_Satterfield-Lowe': 544,
#  'merchant_fraud_Sawayn PLC': 545,
#  'merchant_fraud_Schaefer Ltd': 546,
#  'merchant_fraud_Schaefer, Fay and Hilll': 547,
#  'merchant_fraud_Schaefer, Maggio and Daugherty': 548,
#  'merchant_fraud_Schaefer, McGlynn and Bosco': 549,
#  "merchant_fraud_Schamberger-O'Keefe": 550,
#  'merchant_fraud_Schiller Ltd': 551,
#  'merchant_fraud_Schiller, Blanda and Johnson': 552,
#  'merchant_fraud_Schimmel-Olson': 553,
#  'merchant_fraud_Schmeler Inc': 554,
#  'merchant_fraud_Schmeler, Bashirian and Price': 555,
#  'merchant_fraud_Schmeler-Howe': 556,
#  'merchant_fraud_Schmidt and Sons': 557,
#  'merchant_fraud_Schmidt-Larkin': 558,
#  'merchant_fraud_Schmitt Inc': 559,
#  'merchant_fraud_Schmitt Ltd': 560,
#  'merchant_fraud_Schneider, Hayes and Nikolaus': 561,
#  'merchant_fraud_Schoen Ltd': 562,
#  'merchant_fraud_Schoen, Kuphal and Nitzsche': 563,
#  'merchant_fraud_Schoen, Nienow and Bauch': 564,
#  'merchant_fraud_Schoen-Quigley': 565,
#  'merchant_fraud_Schroeder Group': 566,
#  'merchant_fraud_Schroeder, Hauck and Treutel': 567,
#  'merchant_fraud_Schroeder, Wolff and Hermiston': 568,
#  'merchant_fraud_Schulist Ltd': 569,
#  'merchant_fraud_Schultz, Simonis and Little': 570,
#  'merchant_fraud_Schumm PLC': 571,
#  'merchant_fraud_Schumm, Bauch and Ondricka': 572,
#  'merchant_fraud_Schumm, McLaughlin and Carter': 573,
#  'merchant_fraud_Schuppe LLC': 574,
#  'merchant_fraud_Schuppe, Nolan and Hoeger': 575,
#  'merchant_fraud_Schuppe-Schuppe': 576,
#  'merchant_fraud_Shanahan-Lehner': 577,
#  'merchant_fraud_Shields Inc': 578,
#  'merchant_fraud_Shields-Wunsch': 579,
#  'merchant_fraud_Simonis-Prohaska': 580,
#  'merchant_fraud_Skiles LLC': 581,
#  'merchant_fraud_Skiles-Ankunding': 582,
#  'merchant_fraud_Smith-Stokes': 583,
#  'merchant_fraud_Smitham-Boehm': 584,
#  'merchant_fraud_Smitham-Schiller': 585,
#  'merchant_fraud_Spencer PLC': 586,
#  'merchant_fraud_Spencer-Runolfsson': 587,
#  'merchant_fraud_Spinka Inc': 588,
#  'merchant_fraud_Spinka-Welch': 589,
#  'merchant_fraud_Sporer Inc': 590,
#  'merchant_fraud_Sporer-Keebler': 591,
#  'merchant_fraud_Stamm-Rodriguez': 592,
#  'merchant_fraud_Stamm-Witting': 593,
#  'merchant_fraud_Stanton, Jakubowski and Baumbach': 594,
#  'merchant_fraud_Stark-Batz': 595,
#  'merchant_fraud_Stark-Koss': 596,
#  'merchant_fraud_Stehr, Jewess and Schimmel': 597,
#  'merchant_fraud_Stiedemann Inc': 598,
#  'merchant_fraud_Stiedemann Ltd': 599,
#  'merchant_fraud_Stokes, Christiansen and Sipes': 600,
#  'merchant_fraud_Stoltenberg-Beatty': 601,
#  'merchant_fraud_Stracke-Lemke': 602,
#  'merchant_fraud_Streich Ltd': 603,
#  'merchant_fraud_Streich, Dietrich and Barton': 604,
#  'merchant_fraud_Streich, Hansen and Veum': 605,
#  'merchant_fraud_Streich, Rolfson and Wilderman': 606,
#  'merchant_fraud_Stroman, Hudson and Erdman': 607,
#  'merchant_fraud_Strosin-Cruickshank': 608,
#  'merchant_fraud_Swaniawski, Bahringer and Ledner': 609,
#  'merchant_fraud_Swaniawski, Lowe and Robel': 610,
#  'merchant_fraud_Swaniawski, Nitzsche and Welch': 611,
#  'merchant_fraud_Swift PLC': 612,
#  'merchant_fraud_Swift, Bradtke and Marquardt': 613,
#  'merchant_fraud_Terry Ltd': 614,
#  'merchant_fraud_Terry, Johns and Bins': 615,
#  'merchant_fraud_Terry-Huel': 616,
#  'merchant_fraud_Thiel Ltd': 617,
#  'merchant_fraud_Thiel PLC': 618,
#  'merchant_fraud_Thiel-Thiel': 619,
#  'merchant_fraud_Thompson-Gleason': 620,
#  'merchant_fraud_Tillman LLC': 621,
#  'merchant_fraud_Tillman, Dickinson and Labadie': 622,
#  'merchant_fraud_Tillman, Fritsch and Schmitt': 623,
#  'merchant_fraud_Torp, Muller and Borer': 624,
#  'merchant_fraud_Torp-Labadie': 625,
#  'merchant_fraud_Torp-Lemke': 626,
#  'merchant_fraud_Torphy-Goyette': 627,
#  'merchant_fraud_Torphy-Kertzmann': 628,
#  'merchant_fraud_Towne LLC': 629,
#  'merchant_fraud_Towne, Greenholt and Koepp': 630,
#  'merchant_fraud_Towne, Walker and Borer': 631,
#  'merchant_fraud_Trantow PLC': 632,
#  'merchant_fraud_Treutel-King': 633,
#  'merchant_fraud_Tromp Group': 634,
#  'merchant_fraud_Tromp, Kerluke and Glover': 635,
#  'merchant_fraud_Turcotte, Batz and Buckridge': 636,
#  'merchant_fraud_Turcotte, McKenzie and Koss': 637,
#  'merchant_fraud_Turcotte-Halvorson': 638,
#  'merchant_fraud_Turner LLC': 639,
#  'merchant_fraud_Turner and Sons': 640,
#  'merchant_fraud_Turner, Ruecker and Parisian': 641,
#  'merchant_fraud_Turner, Ziemann and Lehner': 642,
#  'merchant_fraud_Ullrich Ltd': 643,
#  'merchant_fraud_Upton PLC': 644,
#  'merchant_fraud_Vandervort-Funk': 645,
#  'merchant_fraud_Veum-Koelpin': 646,
#  'merchant_fraud_Volkman Ltd': 647,
#  'merchant_fraud_Volkman PLC': 648,
#  'merchant_fraud_Volkman-Predovic': 649,
#  'merchant_fraud_VonRueden Group': 650,
#  'merchant_fraud_Waelchi Inc': 651,
#  'merchant_fraud_Waelchi-Wolf': 652,
#  'merchant_fraud_Walter, Hettinger and Kessler': 653,
#  'merchant_fraud_Waters-Cruickshank': 654,
#  'merchant_fraud_Watsica LLC': 655,
#  'merchant_fraud_Watsica, Haag and Considine': 656,
#  'merchant_fraud_Weber and Sons': 657,
#  'merchant_fraud_Weber, Thiel and Hammes': 658,
#  'merchant_fraud_Weimann, Kuhic and Beahan': 659,
#  'merchant_fraud_Weimann-Lockman': 660,
#  'merchant_fraud_Welch Inc': 661,
#  'merchant_fraud_Welch, Rath and Koepp': 662,
#  'merchant_fraud_White and Sons': 663,
#  'merchant_fraud_Wiegand-Lowe': 664,
#  'merchant_fraud_Wilkinson LLC': 665,
#  'merchant_fraud_Wilkinson Ltd': 666,
#  'merchant_fraud_Wilkinson PLC': 667,
#  'merchant_fraud_Will Ltd': 668,
#  'merchant_fraud_Williamson LLC': 669,
#  'merchant_fraud_Willms, Kris and Bergnaum': 670,
#  'merchant_fraud_Windler LLC': 671,
#  'merchant_fraud_Windler, Goodwin and Kovacek': 672,
#  'merchant_fraud_Wintheiser, Dietrich and Schimmel': 673,
#  'merchant_fraud_Wisozk and Sons': 674,
#  'merchant_fraud_Witting, Beer and Ernser': 675,
#  'merchant_fraud_Wiza LLC': 676,
#  'merchant_fraud_Wiza, Schaden and Stark': 677,
#  'merchant_fraud_Wolf Inc': 678,
#  'merchant_fraud_Wuckert, Wintheiser and Friesen': 679,
#  'merchant_fraud_Wuckert-Goldner': 680,
#  'merchant_fraud_Wuckert-Walter': 681,
#  'merchant_fraud_Yost, Block and Koepp': 682,
#  'merchant_fraud_Yost, Schamberger and Windler': 683,
#  'merchant_fraud_Yost-Rogahn': 684,
#  'merchant_fraud_Zboncak LLC': 685,
#  'merchant_fraud_Zboncak Ltd': 686,
#  'merchant_fraud_Zboncak, Rowe and Murazik': 687,
#  'merchant_fraud_Zemlak Group': 688,
#  'merchant_fraud_Zemlak, Tillman and Cremin': 689,
#  'merchant_fraud_Ziemann-Waters': 690,
#  'merchant_fraud_Zieme, Bode and Dooley': 691,
#  'merchant_fraud_Zulauf LLC': 692}
